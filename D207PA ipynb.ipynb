# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import DataFrame

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
# %matplotlib inline

# %%
import statsmodels.api as sm

# %%
import statistics

# %%
from scipy import stats

# %%
from scipy.stats import chisquare

# %%
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv('churn_clean.csv')

# %%
data = pd.read_csv('churn_clean.csv')

# %%
df = pd.read_csv('churn_clean.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Customer_id                           Interaction         City  \
# 0           0     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b  Point Baker
# 1           1     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524  West Branch
# 2           2     K191035  344d114c-3736-4be5-98f7-c72c281e2d35      Yamhill
# 3           3      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311      Del Mar
# 4           4     K662701  68a861fd-0d20-4e51-a587-8a90407ee574    Needville
#
#   State                 County  Population      Area             Timezone  \
# 0    AK  Prince of Wales-Hyder          38     Urban        America/Sitka
# 1    MI                 Ogemaw       10446     Urban      America/Detroit
# 2    OR                Yamhill        3735     Urban  America/Los_Angeles
# 3    CA              San Diego       13863  Suburban  America/Los_Angeles
# 4    TX              Fort Bend       11352  Suburban      America/Chicago
#
# ...

# %%
df.rename(columns = {'Item1':'Timely response',
        'Item2':'Fixes',
        'Item3':'Replacements',
        'Item4':'Reliability',
        'Item5':'Options',
        'Item6':'Respectfulness',
        'Item7':'Courteous',
        'Item8':'Listening'},
    inplace=True)

# %%
import pylab

# %%
import sklearn

# %%
import statsmodels.api as sm

# %%
import statistics

# %%
from scipy import stats

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import metrics

# %%
from sklearn import preprocessing

# %%
from sklearn.preprocessing import scale

# %%
from sklearn.decomposition import PCA

# %%
from scipy.stats import norm, skew

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn import svm, tree, linear_model, neighbors

# %%
from sklearn import naive_bayes, ensemble, discriminant_analysis, gaussian_process

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.svm import SVC

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, fbeta_score

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import ShuffleSplit

# %%
from sklearn.model_selection import KFold

# %%
from sklearn import feature_selection

# %%
from sklearn import model_selection

# %%
from sklearn import metrics

# %%
from sklearn.metrics import classification_report, precision_recall_curve

# %%
from sklearn.metrics import auc, roc_auc_score, roc_curve

# %%
from sklearn.metrics import make_scorer, recall_score, log_loss

# %%
from sklearn.metrics import average_precision_score

# %%
from scipy.stats import chisquare

# %%
from scipy.stats import chi2_contingency

# %%
churn_df = pd.read_csv('churn_clean.csv')

# %%
df_stats = churn_df.describe()

# %%
print(df_stats)
# Out:
#         Unnamed: 0     Population      Children           Age         Income  \
# count  10000.00000   10000.000000  10000.000000  10000.000000   10000.000000
# mean    4999.50000    9756.562400      1.822500     53.207500   38256.017897
# std     2886.89568   14432.698671      1.925971     18.003457   24747.872761
# min        0.00000       0.000000      0.000000     18.000000     740.660000
# 25%     2499.75000     738.000000      1.000000     41.000000   23660.790000
# 50%     4999.50000    2910.500000      1.000000     53.000000   33186.785000
# 75%     7499.25000   13168.000000      3.000000     65.000000   45504.192500
# max     9999.00000  111850.000000     10.000000     89.000000  258900.700000
#
#        Outage_sec_perweek         Email      Contacts  Yearly_equip_failure  \
# count        10000.000000  10000.000000  10000.000000          10000.000000
# mean            11.452955     12.016000      0.994200              0.398000
# ...

# %%
churn_rate=churn_df.Churn.value_counts() / len(churn_df)
print(churn_rate)
# Out:
# No     0.735
# Yes    0.265
# Name: Churn, dtype: float64

# %%
plt.figure(figsize=(5,5))
labels = ["Yes", "No"]
values = [26.5, 73.5]
plt.pie(values, labels=labels, autopct="%.1f%%")
plt.show()

# %%
churn_df = pd.get_dummies(churn_df, columns =
['Phone','Multiple','InternetService', 'OnlineSecurity',
'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies',
'Contract','PaperlessBilling','PaymentMethod','Churn'], drop_first = True)

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             10000 non-null  int64
#  1   Customer_id                            10000 non-null  object
#  2   Interaction                            10000 non-null  object
#  3   City                                   10000 non-null  object
#  4   State                                  10000 non-null  object
#  5   County                                 10000 non-null  object
#  6   Population                             10000 non-null  int64
#  7   Area                                   10000 non-null  object
#  8   Timezone                               10000 non-null  object
#  9   Job                                    10000 non-null  object
# ...

# %%
def monthly_charge(churn_df):
    if churn_df['MonthlyCharge'] <= 100:
        return "Charge below $100"
    elif (churn_df['MonthlyCharge'] > 100) & (churn_df['MonthlyCharge'] <= 150):
        return "Charge $100 - $150"
    elif (churn_df['MonthlyCharge'] > 150) & (churn_df['MonthlyCharge'] <= 200):
        return "Charge $150 - $200"
    elif (churn_df['MonthlyCharge'] > 200):
        return "Charge Above $200"

# %%
df_clean_2 = churn_df.copy()

# %%
df_clean_2['Monthly_Charge'] = df_clean_2.apply(lambda
                                                df_clean_2:monthly_charge(df_clean_2), axis=1)

# %%
charge1_count = df_clean_2['Monthly_Charge'].value_counts()['Charge below $100']
charge2_count = df_clean_2['Monthly_Charge'].value_counts()['Charge $100 - $150']
charge3_count = df_clean_2['Monthly_Charge'].value_counts()['Charge $150 - $200']
charge4_count = df_clean_2['Monthly_Charge'].value_counts()['Charge Above $200']
charge_total = charge1_count + charge2_count + charge3_count + charge4_count

# %%
pct_charge1 = (charge1_count / charge_total) * 100
pct_charge2 = (charge2_count / charge_total) * 100
pct_charge3 = (charge3_count / charge_total) * 100
pct_charge4 = (charge4_count / charge_total) * 100

# %%
plt.figure(figsize=(5,5))

# %%
values = [pct_charge1, pct_charge2, pct_charge3, pct_charge4]

# %%
labels = ["Charge below $100", "Charge $100 - $150", "Charge $150 - $200"]

# %%
plt.pie(values, autopct="%.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0xfaf3c10>,
# ...
#  [Text(1.097491729671398, 0.07424219354843564, ''),
#   Text(0.5135006743312939, 0.9727882901542898, ''),
#   Text(-1.0827169712587064, -0.1942265691103398, ''),
#   Text(0.7341587208435393, -0.8191525942151305, '')],
#  [Text(0.5986318525480352, 0.040495741935510345, '2.2%'),
#   Text(0.2800912769079784, 0.5306117946296125, '30.2%'),
#   Text(-0.5905728934138398, -0.10594176496927625, '40.9%'),
#   Text(0.40045021136920317, -0.4468105059355257, '26.7%')])

# %%
plt.show()

# %%
df_churn = pd.read_csv('churn_clean.csv')

# %%
df_churn.rename (columns = {
    'Item1':'TimelyResponse',
    'Item2':'Fixes',
    'Item3':'Replacements',
    'Item4':'Reliability',
    'Item5':'Options',
    'Item6':'Respectfulness',
    'Item7':'Courteous',
    'Item8':'Listening'},
                 inplace=True)

# %%
print(df_churn)
# Out:
#       Unnamed: 0 Customer_id                           Interaction  \
# 0              0     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1              1     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2              2     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3              3      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4              4     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
# ...          ...         ...                                   ...
# 9995        9995     M324793  45deb5a2-ae04-4518-bf0b-c82db8dbe4a4
# 9996        9996     D861732  6e96b921-0c09-4993-bbda-a1ac6411061a
# 9997        9997     I243405  e8307ddf-9a01-4fff-bc59-4742e03fd24f
# 9998        9998     I641617  3775ccfc-0052-4107-81ae-9657f81ecdf3
# 9999        9999      T38070  9de5fb6e-bd33-4995-aec8-f01d0172a499
#
#               City State                 County  Population      Area  \
# 0      Point Baker    AK  Prince of Wales-Hyder          38     Urban
# ...

# %%
contingency = pd.crosstab(df['Churn'], df['Respectfulness'])
contingency
# Out:
# Respectfulness    1     2     3     4     5    6  7  8
# Churn
# No              136  1041  2557  2436  1024  146  9  1
# Yes              54   386   888   897   358   64  3  0

# %%
c, p, dof, expected = chi2_contingency(contingency)
print('p-value = ' + str(p))
# Out:
# p-value = 0.7647633348629477

# %%
plt.figure(figsize=(12,8))
sns.heatmap(contingency, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='Respectfulness', ylabel='Churn'>

# %%
df_churn = pd.read_csv('churn_clean.csv')
df_stats = df_churn.describe()

# %%
print(df_stats)
# Out:
#         Unnamed: 0     Population      Children           Age         Income  \
# count  10000.00000   10000.000000  10000.000000  10000.000000   10000.000000
# mean    4999.50000    9756.562400      1.822500     53.207500   38256.017897
# std     2886.89568   14432.698671      1.925971     18.003457   24747.872761
# min        0.00000       0.000000      0.000000     18.000000     740.660000
# 25%     2499.75000     738.000000      1.000000     41.000000   23660.790000
# 50%     4999.50000    2910.500000      1.000000     53.000000   33186.785000
# 75%     7499.25000   13168.000000      3.000000     65.000000   45504.192500
# max     9999.00000  111850.000000     10.000000     89.000000  258900.700000
#
#        Outage_sec_perweek         Email      Contacts  Yearly_equip_failure  \
# count        10000.000000  10000.000000  10000.000000          10000.000000
# mean            11.452955     12.016000      0.994200              0.398000
# ...

# %%
df_churn[['MonthlyCharge', 'Bandwidth_GB_Year','Responses',
          'Respectfulness']].hist()
plt.savefig('churn_pyplot.jpg')
plt.tight_layout()

# %%
df_churn.boxplot(['MonthlyCharge'])
plt.savefig('churn_boxplots.jpg')

# %%
plt.savefig('churn_boxplots.jpg')

# %%
df_churn.boxplot(['Bandwidth_GB_Year'])
plt.savefig('churn_boxplots.jpg')

# %%
df_churn.boxplot(['Responses'])
plt.savefig('churn_boxplots.jpg')

# %%
bivariate = df_churn[['MonthlyCharge', 'Bandwidth_GB_Year', 'Churn',
                      'Responses']]
sns.heatmap(bivariate.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df_churn['MonthlyCharge'], df_churn['Bandwidth_GB_Year'])

# %%
sns.lmplot('MonthlyCharge', 'Bandwidth_GB_Year', data = df_churn,
           hue='Churn', fit_reg=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('Respectfulness', 'Responses', data = df_churn,
           hue='Churn', fit_reg=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")

# %%
data = {'Respectfulness': [1, 2, 3, 1, 2, 3],
        'Responses': [10, 15, 12, 8, 6, 9],
        'Churn': ['Yes', 'Yes', 'Yes', 'No', 'No', 'No']}
df_churn = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35112\1396538492.py in <module>
#       2         'Responses': [10, 15, 12, 8, 6, 9],
#       3         'Churn': ['Yes', 'Yes', 'Yes', 'No', 'No', 'No']}
# ----> 4 df_churn = pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
data = {'Respectfulness': [1, 2, 3, 1, 2, 3],
        'Responses': [10, 15, 12, 8, 6, 9],
        'Churn': ['Yes', 'Yes', 'Yes', 'No', 'No', 'No']}
df_churn = pd.DataFrame(data)

# %%
sns.barplot(x='Respectfulness', y='Responses', hue='Churn', data=df_churn, palette='Set2')
# Out:
# <AxesSubplot:xlabel='Respectfulness', ylabel='Responses'>

# %%
plt.xlabel('Respectfulness')
plt.ylabel('Responses')
plt.title('Stacked Bar Chart of Respectfulness and Responses by Churn')
plt.show()

# %%
jupyter nbconvert --to script my_notebook.ipynb
# Out:
#   File "C:\Users\JoyO'halloran\AppData\Local\Temp\ipykernel_38428\426049048.py", line 1
#     jupyter nbconvert --to script my_notebook.ipynb
#             ^
# SyntaxError: invalid syntax
